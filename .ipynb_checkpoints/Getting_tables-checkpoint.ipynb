# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt; plt.rcdefaults()
from pandas.tools.plotting import table

# %%
def person_id(dataframes):
    for df in dataframes:

        df.replace(['300.0', 300.0, '311.0', 311.0, '305.0', 305.0], ['300.00', '300.00', '311', '311', '305.00', '305.00'], inplace=True)
        df['patient_id']= df.apply(lambda df: str(df['Birth Dt']) + df['Gender Desc'] + str(df['Diag 1']), axis=1)
        # df = df.groupby('patient_id')
        df['Diag 4'] = df['Diag 4'].astype(str)
    return df

# %%
def dropping_duplicates(dataframes):
    for df in dataframes:
        df = df.drop_duplicates(subset='patient_id', keep='last')
    return df

# %%
def given_diagnosis(df, diag1_code, df_desc):
    plt.close('all')
    df = df.loc[df['Diag 1'] == diag1_code]
    count_list= []
    df_2 = df['Diag 2'].astype(str)
    df_3 = df['Diag 3'].astype(str)
    df_4 = df['Diag 4'].astype(str)
    unique = df_2.unique()[1:-1]
    for X in unique:
        count = 0
        for x in df_2:
            if X == x:
                count +=1
        for x in df_3:
            if X == x:
                count +=1
        for x in df_4:
            if X == x:
                count +=1
        count_list.append(count/len(df)*100)

    together = pd.DataFrame(
    {'code': unique,
     'count': count_list
    })
    together = together.sort_values(['count'], ascending=[False])
    #I want to exclude any counts where it was only 1 person
    together = together[together['count'] != 1/len(df)*100]


    #Grab DataFrame rows where column has certain values
    title_desc1= df_desc[df_desc['Diag 1'] == diag1_code]
    title_desc = str(list(title_desc1['Diag Desc 1']))
    title_desc = title_desc.strip("['")
    title_desc = title_desc.strip("']")

    df_desc = df_desc[df_desc['Diag 1'].isin(together['code'])]
    
    return (unique, together, title_desc, df_desc)

# %%
def plotting_graph_table(together, diag1_code, df_desc, title_desc):    
    plt.close('all')
    #creating bar graph
    fig = together.plot(x = 'code', y = 'count', kind = 'bar', color = 'r', figsize = (8,8))
    plt.ylabel('Percent of Patients')
    plt.title('Co-morbidity for {}'.format(diag1_code))
    plt.savefig('Co-morbid_{}.png'.format(diag1_code))

    plt.close('all')


    ax = plt.subplot(111, frame_on=False) # no visible frame
    ax.xaxis.set_visible(False)  # hide the x axis
    ax.yaxis.set_visible(False)  # hide the y axis

    ax.table(cellText=df_desc.values, cellLoc = 'center', rowLoc = 'center',
          loc='center')
         # where df is your data frame
    # plt.title('Co-morbidity for {}'.format(title_desc))
    plt.figtext(.5,.9,'Co-morbidity for {}'.format(title_desc), fontsize=5, ha='center')

    plt.savefig('Co-morbid_{}_table.png'.format(diag1_code),dpi=900)

    print(together)

# %%
def table_of_codes(df):
    df_desc = df[['Diag 1','Diag Desc 1']]
    df_desc = df_desc.drop_duplicates(subset='Diag 1', keep='last')
    return df_desc

# %%
df_jan = pd.read_csv('../data/Chloe Jan clean.csv')
df_feb = pd.read_csv('../data/Chloe Feb clean.csv')
df_mar = pd.read_csv('../data/Chloe March clean.csv')
df_apr = pd.read_csv('../data/Chloe April clean.csv')
df_may = pd.read_csv('../data/Chloe May clean.csv')
df_jun = pd.read_csv('../data/Chloe June clean.csv')

# %%
dataframes = (df_jan, df_feb, df_mar, df_apr, df_may, df_jun)
person_id(dataframes)
# Out:
#        Doctor_Num                   Loc Name            City         Zip  \
# 0               1                 SMMC  Inpt      Osawatomie       66064
# 1               1                 SMMC Outpt   Overland Park       66207
# 2               1  LW Psychiatry Assoc Of KC   Overland Park       66212
# 3               1                 SMMC Outpt          Olathe       66061
# 4               1                 SMMC Outpt        Peculiar       64078
# 5               1                 SMMC  Inpt          Lenexa       66215
# 6               1                 SMMC Outpt     Kansas City       64110
# 7               1                 SMMC  Inpt          Olathe       66062
# 8               1                 SMMC Outpt        Stilwell       66085
# 9               1                 SMMC Outpt        Stilwell       66085
# 10              1                 SMMC Outpt         Leawood       66206
# 11              1                 SMMC  Inpt         Gardner       66030
# 12              1  LW Psychiatry Assoc Of KC     Kansas City       64111
# 13              1  LW Psychiatry Assoc Of KC    Grain Valley       64029
# 14              1                 SMMC  Inpt     Lees Summit  64064-2003
# 15              1  LW Psychiatry Assoc Of KC     Kansas City       66106
# 16              1                 SMMC Outpt     Kansas City       64156
# 17              1                 SMMC  Inpt         Shawnee       66203
# 18              1                 SMMC  Inpt         De Soto       66018
# 19              1                 SMMC  Inpt          Colony       66015
# 20              1                 SMMC  Inpt          Lenexa       66215
# 21              1                 SMMC  Inpt         Shawnee       66216
# 22              1                 SMMC Outpt         Mission       66201
# 23              1  LW Psychiatry Assoc Of KC     Kansas City  66112-9095
# 24              1  LW Psychiatry Assoc Of KC    Roeland Park       66205
# 25              1  LW Psychiatry Assoc Of KC     Kansas City       64155
# 26              1                 SMMC Outpt          Lenexa       66215
# 27              1                 SMMC Outpt   Overland Park       66223
# 28              1                 SMMC  Inpt   Overland Park       66204
# 29              1  LW Psychiatry Assoc Of KC     Kansas City       64109
# ...           ...                        ...             ...         ...
# 23951          11             RMC Adol  Inpt          Odessa       64076
# 23952          11             RMC Adol  Inpt   Overland Park       66214
# 23953          11     RMC Adults And Sr Inpt    Independence       64050
# 23954          11     RMC Adults And Sr Inpt    Independence       64050
# 23955          11     RMC Adults And Sr Inpt    Independence       64050
# 23956          11     RMC Adults And Sr Inpt    Independence       64050
# 23957          11  LW Psychiatry Assoc Of KC         Leawood  66211-2633
# 23958          11             RMC Adol  Inpt          Odessa       64076
# 23959          11             RMC Adol  Inpt   Overland Park       66214
# 23960          11             RMC Adol  Inpt   Overland Park       66214
# 23961          11  LW Psychiatry Assoc Of KC          Belton       64012
# 23962          11  LW Psychiatry Assoc Of KC         Shawnee       66216
# 23963          11  LW Psychiatry Assoc Of KC           Paola       66071
# 23964          11  LW Psychiatry Assoc Of KC          Belton       64012
# 23965          11                RMC Partial     Kansas City       64154
# 23966          11             RMC Adol  Inpt   Overland Park       66214
# 23967          11  LW Psychiatry Assoc Of KC       Greenwood       64034
# 23968          11  LW Psychiatry Assoc Of KC     Lees Summit       64086
# 23969          11  LW Psychiatry Assoc Of KC          Olathe       66062
# 23970          11  LW Psychiatry Assoc Of KC  Bonner Springs       66012
# 23971          11  LW Psychiatry Assoc Of KC   Overland Park       66210
# 23972          11  LW Psychiatry Assoc Of KC    Blue Springs       64014
# 23973          11  LW Psychiatry Assoc Of KC         Shawnee       66216
# 23974          11  LW Psychiatry Assoc Of KC         Liberty       64068
# 23975          11  LW Psychiatry Assoc Of KC         Leawood       66209
# 23976          11  LW Psychiatry Assoc Of KC  Bonner Springs       66012
# 23977          11  LW Psychiatry Assoc Of KC     Kansas City       64136
# 23978          11  LW Psychiatry Assoc Of KC     Kansas City       64131
# 23979          11             RMC Adol  Inpt         Sedalia       65301
# 23980          11             RMC Adol  Inpt     Kansas City       64133
#
#       Gender Desc    Birth Dt  Pat Age  Pat Age in Years  \
# 0          Female  02/14/1969  48 yrs.                48
# 1          Female  03/30/1952  65 yrs.                65
# 2          Female  03/30/1979  38 yrs.                38
# 3          Female  12/02/1977  39 yrs.                39
# 4          Female  08/12/1952  64 yrs.                64
# 5          Female  10/30/1985  31 yrs.                31
# 6            Male  06/19/1975  41 yrs.                41
# 7          Female  12/23/1966  50 yrs.                50
# 8          Female  04/15/1976  41 yrs.                41
# 9          Female  04/15/1976  41 yrs.                41
# 10         Female  04/11/1963  54 yrs.                54
# 11         Female  09/12/1983  33 yrs.                33
# 12           Male  01/26/1979  38 yrs.                38
# 13           Male  02/23/1976  41 yrs.                41
# 14         Female  03/11/1987  30 yrs.                30
# 15           Male  09/24/1959  57 yrs.                57
# 16         Female  12/23/1973  43 yrs.                43
# 17         Female  06/30/1995  21 yrs.                21
# 18         Female  08/17/1989  27 yrs.                27
# 19           Male  09/05/1945  71 yrs.                71
# 20           Male  04/24/1942  75 yrs.                75
# 21           Male  04/22/1959  58 yrs.                58
# 22         Female  11/14/1960  56 yrs.                56
# 23         Female  06/07/1972  44 yrs.                44
# 24           Male  12/23/1985  31 yrs.                31
# 25         Female  04/22/1966  51 yrs.                51
# 26         Female  10/22/1972  44 yrs.                44
# 27         Female  10/06/1990  26 yrs.                26
# 28         Female  01/25/1966  51 yrs.                51
# 29           Male  01/13/1973  44 yrs.                44
# ...           ...         ...      ...               ...
# 23951      Female  04/18/2002  15 yrs.                15
# 23952      Female  09/14/1999  17 yrs.                17
# 23953      Female  09/09/1989  27 yrs.                27
# 23954      Female  09/09/1989  27 yrs.                27
# 23955      Female  09/09/1989  27 yrs.                27
# 23956      Female  09/09/1989  27 yrs.                27
# 23957        Male  05/23/1980  37 yrs.                37
# 23958      Female  04/18/2002  15 yrs.                15
# 23959      Female  09/14/1999  17 yrs.                17
# 23960      Female  09/14/1999  17 yrs.                17
# 23961        Male  06/20/2006  10 yrs.                10
# 23962        Male  01/30/2003  14 yrs.                14
# 23963        Male  04/30/1988  29 yrs.                29
# 23964        Male  08/21/1992  24 yrs.                24
# 23965      Female  08/28/2001  15 yrs.                15
# 23966      Female  09/14/1999  17 yrs.                17
# 23967        Male  08/15/2004  12 yrs.                12
# 23968      Female  12/11/1963  53 yrs.                53
# 23969        Male  02/15/1986  31 yrs.                31
# 23970        Male  02/18/1997  20 yrs.                20
# 23971        Male  09/13/1966  50 yrs.                50
# 23972        Male  02/18/2004  13 yrs.                13
# 23973        Male  08/02/1999  17 yrs.                17
# 23974        Male  02/06/1961  56 yrs.                56
# 23975      Female  03/14/1988  29 yrs.                29
# 23976        Male  02/18/1997  20 yrs.                20
# 23977      Female  10/21/2006  10 yrs.                10
# 23978      Female  02/05/1972  45 yrs.                45
# 23979      Female  05/03/1999  18 yrs.                18
# 23980        Male  02/03/1998  19 yrs.                19
#
#        Pat Age in Years (DOS)         Pat Type           ...            \
# 0                          46         Hospital           ...
# 1                          63         Hospital           ...
# 2                          36  Office Followup           ...
# 3                          37         Hospital           ...
# 4                          62         Hospital           ...
# 5                          29         Hospital           ...
# 6                          40         Hospital           ...
# 7                          48         Hospital           ...
# 8                          39         Hospital           ...
# 9                          39         Hospital           ...
# 10                         52         Hospital           ...
# 11                         31         Hospital           ...
# 12                         36  Office Followup           ...
# 13                         39  Office Followup           ...
# 14                         28         Hospital           ...
# 15                         55  Office Followup           ...
# 16                         41         Hospital           ...
# 17                         19         Hospital           ...
# 18                         25         Hospital           ...
# 19                         69         Hospital           ...
# 20                         73         Hospital           ...
# 21                         56         Hospital           ...
# 22                         54         Hospital           ...
# 23                         43  Office Followup           ...
# 24                         29  Office Followup           ...
# 25                         49  Office Followup           ...
# 26                         42         Hospital           ...
# 27                         24         Hospital           ...
# 28                         49         Hospital           ...
# 29                         42  Office Followup           ...
# ...                       ...              ...           ...
# 23951                      13         Hospital           ...
# 23952                      15         Hospital           ...
# 23953                      25         Hospital           ...
# 23954                      25         Hospital           ...
# 23955                      25         Hospital           ...
# 23956                      25         Hospital           ...
# 23957                      35  Office Followup           ...
# 23958                      13         Hospital           ...
# 23959                      15         Hospital           ...
# 23960                      15         Hospital           ...
# 23961                       8  Office Followup           ...
# 23962                      12  Office Followup           ...
# 23963                      27  Office Followup           ...
# 23964                      22  Office Followup           ...
# 23965                      13         Hospital           ...
# 23966                      15         Hospital           ...
# 23967                      10  Office Followup           ...
# 23968                      51  Office Followup           ...
# 23969                      29  Office Followup           ...
# 23970                      18  Office Followup           ...
# 23971                      48  Office Followup           ...
# 23972                      11  Office Followup           ...
# 23973                      15  Office Followup           ...
# 23974                      54  Office Followup           ...
# 23975                      27  Office Followup           ...
# 23976                      18  Office Followup           ...
# 23977                       8  Office Followup           ...
# 23978                      43  Office Followup           ...
# 23979                      16         Hospital           ...
# 23980                      17         Hospital           ...
#
#                                              Diag Desc 1  \
# 0                          Bipolar disorder, unspecified
# 1                          Bipolar disorder, unspecified
# 2                         Obsessive-compulsive disorders
# 3                  Schizoaffective disorder, unspecified
# 4                  Schizoaffective disorder, unspecified
# 5      Other and unspecified alcohol dependence, unsp...
# 6      Major depressive affective disorder, recurrent...
# 7      Major depressive affective disorder, recurrent...
# 8      Major depressive affective disorder, recurrent...
# 9      Major depressive affective disorder, recurrent...
# 10     Major depressive affective disorder, recurrent...
# 11     Major depressive affective disorder, recurrent...
# 12     Attention deficit disorder of childhood with h...
# 13     Major depressive affective disorder, recurrent...
# 14     Major depressive affective disorder, single ep...
# 15                         Bipolar disorder, unspecified
# 16     Bipolar I disorder, most recent episode (or cu...
# 17                 Schizoaffective disorder, unspecified
# 18     Major depressive affective disorder, recurrent...
# 19                    Unspecified episodic mood disorder
# 20     Major depressive affective disorder, recurrent...
# 21     Bipolar I disorder, most recent episode (or cu...
# 22     Bipolar I disorder, most recent episode (or cu...
# 23     Major depressive affective disorder, recurrent...
# 24     Attention deficit disorder of childhood with h...
# 25                         Bipolar disorder, unspecified
# 26     Bipolar I disorder, most recent episode (or cu...
# 27                 Schizoaffective disorder, unspecified
# 28     Major depressive affective disorder, single ep...
# 29                    Panic disorder without agoraphobia
# ...                                                  ...
# 23951  Major depressive affective disorder, recurrent...
# 23952  Major depressive affective disorder, recurrent...
# 23953  Major depressive affective disorder, recurrent...
# 23954  Major depressive affective disorder, recurrent...
# 23955  Major depressive affective disorder, recurrent...
# 23956  Major depressive affective disorder, recurrent...
# 23957  Bipolar I disorder, most recent episode (or cu...
# 23958  Major depressive affective disorder, recurrent...
# 23959  Major depressive affective disorder, recurrent...
# 23960  Major depressive affective disorder, recurrent...
# 23961  Attention deficit disorder of childhood with h...
# 23962     Other and unspecified bipolar disorders, other
# 23963  Major depressive affective disorder, recurrent...
# 23964  Major depressive affective disorder, recurrent...
# 23965                 Unspecified episodic mood disorder
# 23966  Major depressive affective disorder, recurrent...
# 23967                         Anxiety state, unspecified
# 23968                      Posttraumatic stress disorder
# 23969  Bipolar I disorder, most recent episode (or cu...
# 23970                      Bipolar disorder, unspecified
# 23971  Major depressive affective disorder, recurrent...
# 23972  Attention deficit disorder of childhood with h...
# 23973                         Anxiety state, unspecified
# 23974  Bipolar I disorder, most recent episode (or cu...
# 23975  Bipolar I disorder, most recent episode (or cu...
# 23976                      Bipolar disorder, unspecified
# 23977                     Obsessive-compulsive disorders
# 23978  Major depressive affective disorder, recurrent...
# 23979                      Bipolar disorder, unspecified
# 23980  Major depressive affective disorder, recurrent...
#
#                                              Diag Desc 2  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11     Other and unspecified alcohol dependence, unsp...
# 12                                                   NaN
# 13                                                   NaN
# 14                          Generalized anxiety disorder
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                       Agoraphobia with panic disorder
# 19                                                   NaN
# 20                                                   NaN
# 21                    Panic disorder without agoraphobia
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                         Posttraumatic stress disorder
# 27                                                   NaN
# 28                                 Somatization disorder
# 29                                                   NaN
# ...                                                  ...
# 23951                                                NaN
# 23952                                                NaN
# 23953                                                NaN
# 23954                                                NaN
# 23955                                                NaN
# 23956                                                NaN
# 23957                                                NaN
# 23958                                                NaN
# 23959                                                NaN
# 23960                                                NaN
# 23961                                                NaN
# 23962  Attention deficit disorder of childhood withou...
# 23963                                                NaN
# 23964                                                NaN
# 23965                                                NaN
# 23966                                                NaN
# 23967                 Panic disorder without agoraphobia
# 23968                                                NaN
# 23969                                                NaN
# 23970                                                NaN
# 23971                                                NaN
# 23972                                                NaN
# 23973                                                NaN
# 23974                                                NaN
# 23975                                                NaN
# 23976                                                NaN
# 23977                                                NaN
# 23978                                                NaN
# 23979                                                NaN
# 23980                                                NaN
#
#                               Diag Desc 3                   Diag Desc 4  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3                                     NaN                           NaN
# 4                                     NaN                           NaN
# 5                                     NaN                           NaN
# 6                                     NaN                           NaN
# 7                                     NaN                           NaN
# 8                                     NaN                           NaN
# 9                                     NaN                           NaN
# 10                                    NaN                           NaN
# 11                                    NaN                           NaN
# 12                                    NaN                           NaN
# 13                                    NaN                           NaN
# 14                                    NaN                           NaN
# 15                                    NaN                           NaN
# 16                                    NaN                           NaN
# 17                                    NaN                           NaN
# 18          Posttraumatic stress disorder  Generalized anxiety disorder
# 19                                    NaN                           NaN
# 20                                    NaN                           NaN
# 21                                    NaN                           NaN
# 22                                    NaN                           NaN
# 23                                    NaN                           NaN
# 24                                    NaN                           NaN
# 25                                    NaN                           NaN
# 26           Generalized anxiety disorder                           NaN
# 27                                    NaN                           NaN
# 28           Generalized anxiety disorder                           NaN
# 29                                    NaN                           NaN
# ...                                   ...                           ...
# 23951                                 NaN                           NaN
# 23952                                 NaN                           NaN
# 23953                                 NaN                           NaN
# 23954                                 NaN                           NaN
# 23955                                 NaN                           NaN
# 23956                                 NaN                           NaN
# 23957                                 NaN                           NaN
# 23958                                 NaN                           NaN
# 23959                                 NaN                           NaN
# 23960                                 NaN                           NaN
# 23961                                 NaN                           NaN
# 23962  Unspecified disturbance of conduct                           NaN
# 23963                                 NaN                           NaN
# 23964                                 NaN                           NaN
# 23965                                 NaN                           NaN
# 23966                                 NaN                           NaN
# 23967                                 NaN                           NaN
# 23968                                 NaN                           NaN
# 23969                                 NaN                           NaN
# 23970                                 NaN                           NaN
# 23971                                 NaN                           NaN
# 23972                                 NaN                           NaN
# 23973                                 NaN                           NaN
# 23974                                 NaN                           NaN
# 23975                                 NaN                           NaN
# 23976                                 NaN                           NaN
# 23977                                 NaN                           NaN
# 23978                                 NaN                           NaN
# 23979                                 NaN                           NaN
# 23980                                 NaN                           NaN
#
#              Place Of Serv         Fin Class Admitting          Referring  \
# 0       Inpatient Hospital          Medicare       NaN                NaN
# 1      Outpatient Hospital        Commercial       NaN                NaN
# 2                   Office        Commercial       NaN                NaN
# 3      Outpatient Hospital        Commercial       NaN                NaN
# 4      Outpatient Hospital              BCBS       NaN                NaN
# 5       Inpatient Hospital           Charity       NaN                NaN
# 6      Outpatient Hospital              BCBS       NaN                NaN
# 7       Inpatient Hospital        Commercial       NaN                NaN
# 8      Outpatient Hospital              BCBS       NaN                NaN
# 9      Outpatient Hospital              BCBS       NaN                NaN
# 10     Outpatient Hospital              BCBS       NaN                NaN
# 11      Inpatient Hospital              BCBS       NaN                NaN
# 12                  Office              BCBS       NaN                NaN
# 13                  Office        Commercial       NaN                NaN
# 14      Inpatient Hospital              BCBS       NaN                NaN
# 15                  Office        Commercial       NaN                NaN
# 16     Outpatient Hospital        Commercial       NaN                NaN
# 17      Inpatient Hospital  Managed Medicaid       NaN                NaN
# 18      Inpatient Hospital          Medicare       NaN                NaN
# 19      Inpatient Hospital          Medicare       NaN                NaN
# 20      Inpatient Hospital          Medicare       NaN                NaN
# 21      Inpatient Hospital  Managed Medicaid       NaN                NaN
# 22                  Office          Medicare       NaN  Sagduyu MD, Kemal
# 23                  Office              BCBS       NaN                NaN
# 24                  Office        Commercial       NaN                NaN
# 25                  Office              BCBS       NaN                NaN
# 26     Outpatient Hospital        Commercial       NaN                NaN
# 27     Outpatient Hospital  Managed Medicaid       NaN                NaN
# 28      Inpatient Hospital              BCBS       NaN                NaN
# 29                  Office              BCBS       NaN                NaN
# ...                    ...               ...       ...                ...
# 23951   Inpatient Hospital          Self Pay       NaN                NaN
# 23952   Inpatient Hospital          Self Pay       NaN                NaN
# 23953   Inpatient Hospital          Self Pay       NaN                NaN
# 23954   Inpatient Hospital          Self Pay       NaN                NaN
# 23955   Inpatient Hospital          Self Pay       NaN                NaN
# 23956   Inpatient Hospital          Self Pay       NaN                NaN
# 23957               Office          Self Pay       NaN                NaN
# 23958   Inpatient Hospital          Self Pay       NaN                NaN
# 23959   Inpatient Hospital          Self Pay       NaN                NaN
# 23960   Inpatient Hospital          Self Pay       NaN                NaN
# 23961               Office          Self Pay       NaN                NaN
# 23962               Office               NaN       NaN                NaN
# 23963               Office               NaN       NaN                NaN
# 23964               Office               NaN       NaN                NaN
# 23965  Outpatient Hospital          Self Pay       NaN                NaN
# 23966   Inpatient Hospital               NaN       NaN                NaN
# 23967               Office          Self Pay       NaN                NaN
# 23968               Office          Self Pay       NaN                NaN
# 23969               Office        Commercial       NaN                NaN
# 23970               Office              BCBS       NaN                NaN
# 23971               Office          Self Pay       NaN                NaN
# 23972               Office          Self Pay       NaN                NaN
# 23973               Office               NaN       NaN                NaN
# 23974               Office               NaN       NaN                NaN
# 23975               Office               NaN       NaN                NaN
# 23976               Office          Self Pay       NaN                NaN
# 23977               Office               NaN       NaN                NaN
# 23978               Office              BCBS       NaN                NaN
# 23979   Inpatient Hospital          Medicaid       NaN                NaN
# 23980   Inpatient Hospital        Commercial       NaN                NaN
#
#                         Pat Sts              patient_id
# 0              Hospital Patient  02/14/1969Female296.80
# 1              Hospital Patient  03/30/1952Female296.80
# 2                           EHR   03/30/1979Female300.3
# 3           Pending Collections  12/02/1977Female295.70
# 4                           EHR  08/12/1952Female295.70
# 5              Hospital Patient  10/30/1985Female303.90
# 6              Hospital Patient    06/19/1975Male296.33
# 7              Hospital Patient  12/23/1966Female296.33
# 8              Hospital Patient  04/15/1976Female296.33
# 9              Hospital Patient  04/15/1976Female296.33
# 10             Hospital Patient  04/11/1963Female296.33
# 11             Hospital Patient  09/12/1983Female296.32
# 12                          EHR    01/26/1979Male314.01
# 13                          EHR    02/23/1976Male296.32
# 14             Hospital Patient  03/11/1987Female296.23
# 15                          EHR    09/24/1959Male296.80
# 16                          EHR  12/23/1973Female296.64
# 17             Hospital Patient  06/30/1995Female295.70
# 18             Hospital Patient  08/17/1989Female296.33
# 19             Hospital Patient    09/05/1945Male296.90
# 20                          EHR    04/24/1942Male296.33
# 21     Discharged From Practice    04/22/1959Male296.53
# 22             Hospital Patient  11/14/1960Female296.63
# 23                          EHR  06/07/1972Female296.32
# 24                          EHR    12/23/1985Male314.01
# 25                          EHR  04/22/1966Female296.80
# 26             Hospital Patient  10/22/1972Female296.63
# 27                       Active  10/06/1990Female295.70
# 28             Hospital Patient  01/25/1966Female296.23
# 29                          EHR    01/13/1973Male300.01
# ...                         ...                     ...
# 23951          Hospital Patient  04/18/2002Female296.33
# 23952          Hospital Patient  09/14/1999Female296.33
# 23953          Hospital Patient  09/09/1989Female296.33
# 23954          Hospital Patient  09/09/1989Female296.33
# 23955          Hospital Patient  09/09/1989Female296.33
# 23956          Hospital Patient  09/09/1989Female296.33
# 23957                       EHR    05/23/1980Male296.53
# 23958          Hospital Patient  04/18/2002Female296.33
# 23959          Hospital Patient  09/14/1999Female296.33
# 23960          Hospital Patient  09/14/1999Female296.33
# 23961                       EHR    06/20/2006Male314.01
# 23962                       EHR    01/30/2003Male296.89
# 23963    Chart Scanned Into EHR    04/30/1988Male296.32
# 23964                       EHR    08/21/1992Male296.33
# 23965          Hospital Patient  08/28/2001Female296.90
# 23966          Hospital Patient  09/14/1999Female296.33
# 23967                       EHR    08/15/2004Male300.00
# 23968                       EHR  12/11/1963Female309.81
# 23969    Chart Scanned Into EHR    02/15/1986Male296.63
# 23970                       EHR    02/18/1997Male296.80
# 23971                       EHR    09/13/1966Male296.32
# 23972                       EHR    02/18/2004Male314.01
# 23973                       EHR    08/02/1999Male300.00
# 23974                       EHR    02/06/1961Male296.55
# 23975                       EHR  03/14/1988Female296.65
# 23976                       EHR    02/18/1997Male296.80
# 23977                       EHR   10/21/2006Female300.3
# 23978    Chart Scanned Into EHR  02/05/1972Female296.32
# 23979          Hospital Patient  05/03/1999Female296.80
# 23980          Hospital Patient    02/03/1998Male296.33
#
# [23981 rows x 27 columns]

# %%
frames = [df_jan, df_feb, df_mar,df_apr, df_may, df_jun]

df_combo = pd.concat(frames)
df_combo = df_combo.drop_duplicates(subset='patient_id', keep='last')

# %%
lst_codes = df_combo['Diag 1'].astype(str)

# %%
df_combo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19830 entries, 274 to 23980
# Data columns (total 27 columns):
# Doctor_Num                19830 non-null int64
# Loc Name                  19830 non-null object
# City                      19830 non-null object
# Zip                       19830 non-null object
# Gender Desc               19830 non-null object
# Birth Dt                  19830 non-null object
# Pat Age                   19830 non-null object
# Pat Age in Years          19830 non-null int64
# Pat Age in Years (DOS)    19830 non-null int64
# Pat Type                  19829 non-null object
# Dt of Svc                 19830 non-null object
# CPT4                      19830 non-null object
# CPT4 Desc                 19830 non-null object
# Diag 1                    19157 non-null object
# Diag 2                    6261 non-null object
# Diag 3                    2202 non-null object
# Diag 4                    19830 non-null object
# Diag Desc 1               19130 non-null object
# Diag Desc 2               6241 non-null object
# Diag Desc 3               2166 non-null object
# Diag Desc 4               458 non-null object
# Place Of Serv             19830 non-null object
# Fin Class                 18041 non-null object
# Admitting                 0 non-null float64
# Referring                 690 non-null object
# Pat Sts                   19827 non-null object
# patient_id                19830 non-null object
# dtypes: float64(1), int64(3), object(23)
# memory usage: 4.2+ MB

# %%
dropping_col = ['Loc Name', 'City', 'Zip', 'Pat Age', 'Referring']
df_combo = df_combo.drop((x for x in dropping_col), axis = 1)

# %%
df_combo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19830 entries, 274 to 23980
# Data columns (total 21 columns):
# Doctor_Num                19830 non-null int64
# Gender Desc               19830 non-null object
# Birth Dt                  19830 non-null object
# Pat Age in Years          19830 non-null int64
# Pat Age in Years (DOS)    19830 non-null int64
# Pat Type                  19829 non-null object
# Dt of Svc                 19830 non-null object
# CPT4                      19830 non-null object
# CPT4 Desc                 19830 non-null object
# Diag 1                    19157 non-null object
# Diag 2                    6261 non-null object
# Diag 3                    2202 non-null object
# Diag 4                    19830 non-null object
# Diag Desc 1               19130 non-null object
# Diag Desc 2               6241 non-null object
# Diag Desc 3               2166 non-null object
# Diag Desc 4               458 non-null object
# Place Of Serv             19830 non-null object
# Fin Class                 18041 non-null object
# Pat Sts                   19827 non-null object
# patient_id                19830 non-null object
# dtypes: int64(3), object(18)
# memory usage: 3.3+ MB

# %%
df_combo = df_combo[df_combo['Diag 1'].notnull()]

# %%
df_desc = df_combo[['Diag 1','Diag Desc 1']]
df_desc = df_desc.drop_duplicates(subset='Diag 1', keep='last')
given_diagnosis(df_combo, '314.01', df_desc)
# Out:
# (array(['311', '300.02', '300.00', '296.36', '296.31', '296.56', '305.20',
#         '296.35', '300.29', '296.26', '300.01', '296.8', '299.00'], dtype=object),
#        code     count
#  2   300.00  2.197802
#  3   296.36  0.824176
#  1   300.02  0.755495
#  0      311  0.480769
#  10  300.01  0.274725
#  7   296.35  0.206044
#  4   296.31  0.137363
#  9   296.26  0.137363,
#  'Attention deficit disorder of childhood with hyperactivity',
#         Diag 1                                        Diag Desc 1
#  17902  296.26  Major depressive affective disorder, single ep...
#  21925  296.36  Major depressive affective disorder, recurrent...
#  21946  296.31  Major depressive affective disorder, recurrent...
#  21950  296.35  Major depressive affective disorder, recurrent...
#  23533  300.02                       Generalized anxiety disorder
#  23572  300.01                 Panic disorder without agoraphobia
#  23945     311      Depressive disorder, not elsewhere classified
#  23973  300.00                         Anxiety state, unspecified)

# %%
lst_codes = df_combo['Diag 1'].astype(str)
lst_codes = lst_codes.unique()
print(lst_codes)
# Out:
# ['303.90' '314.01' '300.02' '296.32' '296.23' '298.9' '309.81' '295.70'
#  '296.35' '296.63' '303.92' '296.62' '300.20' '296.89' '295.32' '296.33'
#  '300.3' '296.90' '300.4' '309.28' '296.80' '295.64' '290.20' '296.64'
#  '296.54' '300.00' '304.80' '293.0' 'V70.1' '296.52' '294.10' '296.31'
#  '305.20' '296.36' '290.3' '295.30' '301.13' '305.60' '309.0' '305.00'
#  '296.53' 'V62.82' '296.51' '300.01' '295.74' '300.21' '296.44' '296.30'
#  '296.56' '294.11' '295.73' '311' '296.65' '295.72' '296.25' '300.23'
#  '296.55' '296.22' '299.00' '296.41' '296.61' '294.8' '296.34' '295.34'
#  '331.0' '296.46' '296.45' '290.42' '296.66' '290.21' '290.41' '331.82'
#  '304.02' '296.43' '295.90' '300.11' '296.21' '300.29' '293.81' '312.30'
#  '307.42' '309.24' '296.42' '295.92' '296.60' '290.43' '295.33' '301.9'
#  '290.13' '295.35' '296.50' '304.03' '296.20' '304.00' '304.90' '304.81'
#  '294.9' '290.40' '303.93' '296.26' '305.40' '295.75' '309.29' '301.4'
#  '290.11' '295.80' '295.82' '295.95' '305.23' '293.83' '305.01' '309.89'
#  '296.24' '307.1' '296.02' '314.00' '295.62' '297.1' '296.00' '303.91'
#  '301.83' '290.10' '296.99' '296.40' '308.3' '304.01' '303.03' '312.34'
#  '296.12' '296.05' '293.82' '295.83' '305.02' '305.50' '307.51' '304.22'
#  '292.11' '293.1' '299.80' '305.22' '317' '295.94' '292.12' '312.9' '298.8'
#  '295.02' '292.84' '307.23' '296.15' '314.1' '309.21' '291.2' '304.10'
#  '295.22']

# %%
def ranking_codes(df,lst_codes, df_desc):
    
    ranking_count = []
    ranking_codes = []
    for x in lst_codes:
        df = df.loc[df['Diag 1'] == str(x)]
        count_list= []
        df_2 = df['Diag 2'].astype(str)
        df_3 = df['Diag 3'].astype(str)
        df_4 = df['Diag 4'].astype(str)
        unique = df_2.unique()[1:-1]
        for X in unique:
            count = 0
            for x in df_2:
                if X == x:
                    count +=1
            for x in df_3:
                if X == x:
                    count +=1
            for x in df_4:
                if X == x:
                    count +=1
            count_list.append(count/len(df)*100)

        together = pd.DataFrame(
        {'code': unique,
         'count': count_list
        })
        together = together.sort_values(['count'], ascending=[False])
        if together.empty:
            continue
        else:    
            ranking_codes.append(together['code'][0])
            ranking_count.append(together['count'][0])
        print (together['code'][0])
        print (together['count'][0])
    
    return (ranking_count, ranking_codes)

# %%
ranking_codes(df_combo, lst_codes, df_desc)
ranking_df = pd.DataFrame(
    {'code': ranking_codes,
     'count': ranking_count
    })
ranking_df = ranking_df.sort('count', ascending=False)
# Out:
# 311
# 13.8790035587
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-3fae5c5f24d1> in <module>()
#       2 ranking_df = pd.DataFrame(
#       3     {'code': ranking_codes,
# ----> 4      'count': ranking_count
#       5     })
#       6 ranking_df = ranking_df.sort('count', ascending=False)
#
# NameError: name 'ranking_count' is not defined

# %%
df_desc[116:]
# Out:
#        Diag 1                                        Diag Desc 1
# 21899  296.43  Bipolar I disorder, most recent episode (or cu...
# 21907  296.51  Bipolar I disorder, most recent episode (or cu...
# 21925  296.36  Major depressive affective disorder, recurrent...
# 21929  296.22  Major depressive affective disorder, single ep...
# 21930  296.25  Major depressive affective disorder, single ep...
# 21931  290.20           Senile dementia with delusional features
# 21936  296.99             Other specified episodic mood disorder
# 21942  296.21  Major depressive affective disorder, single ep...
# 21946  296.31  Major depressive affective disorder, recurrent...
# 21950  296.35  Major depressive affective disorder, recurrent...
# 21953  303.90  Other and unspecified alcohol dependence, unsp...
# 23245  295.72                  Schizoaffective disorder, chronic
# 23413  296.44  Bipolar I disorder, most recent episode (or cu...
# 23533  300.02                       Generalized anxiety disorder
# 23572  300.01                 Panic disorder without agoraphobia
# 23624  295.22        Catatonic type schizophrenia, chronic state
# 23801  295.32         Paranoid type schizophrenia, chronic state
# 23847  295.70              Schizoaffective disorder, unspecified
# 23883   298.9                              Unspecified psychosis
# 23885  299.00         Autistic disorder, current or active state
# 23887  296.34  Major depressive affective disorder, recurrent...
# 23890  296.64  Bipolar I disorder, most recent episode (or cu...
# 23923  296.23  Major depressive affective disorder, single ep...
# 23944  296.62  Bipolar I disorder, most recent episode (or cu...
# 23945     311      Depressive disorder, not elsewhere classified
# 23957  296.53  Bipolar I disorder, most recent episode (or cu...
# 23962  296.89     Other and unspecified bipolar disorders, other
# 23965  296.90                 Unspecified episodic mood disorder
# 23968  309.81                      Posttraumatic stress disorder
# 23969  296.63  Bipolar I disorder, most recent episode (or cu...
# 23972  314.01  Attention deficit disorder of childhood with h...
# 23973  300.00                         Anxiety state, unspecified
# 23974  296.55  Bipolar I disorder, most recent episode (or cu...
# 23975  296.65  Bipolar I disorder, most recent episode (or cu...
# 23977   300.3                     Obsessive-compulsive disorders
# 23978  296.32  Major depressive affective disorder, recurrent...
# 23979  296.80                      Bipolar disorder, unspecified
# 23980  296.33  Major depressive affective disorder, recurrent...

# %%
df_combo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19157 entries, 274 to 23980
# Data columns (total 21 columns):
# Doctor_Num                19157 non-null int64
# Gender Desc               19157 non-null object
# Birth Dt                  19157 non-null object
# Pat Age in Years          19157 non-null int64
# Pat Age in Years (DOS)    19157 non-null int64
# Pat Type                  19156 non-null object
# Dt of Svc                 19157 non-null object
# CPT4                      19157 non-null object
# CPT4 Desc                 19157 non-null object
# Diag 1                    19157 non-null object
# Diag 2                    6261 non-null object
# Diag 3                    2202 non-null object
# Diag 4                    19157 non-null object
# Diag Desc 1               18969 non-null object
# Diag Desc 2               6190 non-null object
# Diag Desc 3               2143 non-null object
# Diag Desc 4               447 non-null object
# Place Of Serv             19157 non-null object
# Fin Class                 17399 non-null object
# Pat Sts                   19156 non-null object
# patient_id                19157 non-null object
# dtypes: int64(3), object(18)
# memory usage: 3.2+ MB

# %%
df_combo['Pat_Age_0_20'] = df_combo['Pat Age in Years'].apply(lambda x: 1 if x<=20 else 0)

# %%
df_combo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19157 entries, 274 to 23980
# Data columns (total 26 columns):
# Doctor_Num                19157 non-null int64
# Gender Desc               19157 non-null object
# Birth Dt                  19157 non-null object
# Pat Age in Years          19157 non-null int64
# Pat Age in Years (DOS)    19157 non-null int64
# Pat Type                  19156 non-null object
# Dt of Svc                 19157 non-null object
# CPT4                      19157 non-null object
# CPT4 Desc                 19157 non-null object
# Diag 1                    19157 non-null object
# Diag 2                    6261 non-null object
# Diag 3                    2202 non-null object
# Diag 4                    19157 non-null object
# Diag Desc 1               18969 non-null object
# Diag Desc 2               6190 non-null object
# Diag Desc 3               2143 non-null object
# Diag Desc 4               447 non-null object
# Place Of Serv             19157 non-null object
# Fin Class                 17399 non-null object
# Pat Sts                   19156 non-null object
# patient_id                19157 non-null object
# Pat_Age_0_20              19157 non-null int64
# Pat_Age_21_40             19157 non-null int64
# Pat_Age_41_60             19157 non-null int64
# Pat_Age_61_80             19157 non-null int64
# Pat_Age_81_110            19157 non-null int64
# dtypes: int64(8), object(18)
# memory usage: 3.9+ MB

# %%
df_combo['Pat_Age_0_20'].unique()
# Out:
# array([0, 1])

# %%
df_combo['Pat_Age_0_20'].sum()
# Out:
# 2541

# %%
df_combo['Pat_Age_21_40'] = df_combo['Pat Age in Years'].apply(lambda x: 1 if x<=40 and x>=21 else 0)

# %%
df_combo['Pat_Age_21_40'].sum()
# Out:
# 6042

# %%
df_combo['Pat_Age_41_60'] = df_combo['Pat Age in Years'].apply(lambda x: 1 if x<=60 and x>=41 else 0)

# %%
df_combo['Pat_Age_41_60'].sum()
# Out:
# 5928

# %%
df_combo['Pat_Age_61_80'] = df_combo['Pat Age in Years'].apply(lambda x: 1 if x<=80 and x>=61 else 0)

# %%
df_combo['Pat_Age_61_80'].sum()
# Out:
# 3660

# %%
df_combo['Pat_Age_81_110'] = df_combo['Pat Age in Years'].apply(lambda x: 1 if x<110 and x>=81 else 0)

# %%
df_combo['Pat_Age_81_110'].sum()
# Out:
# 986

# %%
df_combo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19157 entries, 274 to 23980
# Data columns (total 26 columns):
# Doctor_Num                19157 non-null int64
# Gender Desc               19157 non-null object
# Birth Dt                  19157 non-null object
# Pat Age in Years          19157 non-null int64
# Pat Age in Years (DOS)    19157 non-null int64
# Pat Type                  19156 non-null object
# Dt of Svc                 19157 non-null object
# CPT4                      19157 non-null object
# CPT4 Desc                 19157 non-null object
# Diag 1                    19157 non-null object
# Diag 2                    6261 non-null object
# Diag 3                    2202 non-null object
# Diag 4                    19157 non-null object
# Diag Desc 1               18969 non-null object
# Diag Desc 2               6190 non-null object
# Diag Desc 3               2143 non-null object
# Diag Desc 4               447 non-null object
# Place Of Serv             19157 non-null object
# Fin Class                 17399 non-null object
# Pat Sts                   19156 non-null object
# patient_id                19157 non-null object
# Pat_Age_0_20              19157 non-null int64
# Pat_Age_21_40             19157 non-null int64
# Pat_Age_41_60             19157 non-null int64
# Pat_Age_61_80             19157 non-null int64
# Pat_Age_81_110            19157 non-null int64
# dtypes: int64(8), object(18)
# memory usage: 3.9+ MB
